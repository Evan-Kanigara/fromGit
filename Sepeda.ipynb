# %%
import pandas as pd
import seaborn as sns

# %%
pd.read_csv("F:\KULIAH\PENGANGGURAN\Digitalent\Kelas A\Materi IBM\Challenge\\q22018.csv")
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2383648                    393             7018    1/1/2018 0:47
# 1       2383649                    625             7184    1/1/2018 0:52
# 2       2383650                    233             7235    1/1/2018 0:55
# 3       2383651                   1138             7202    1/1/2018 0:57
# 4       2383652                    703             7004    1/1/2018 1:00
# ...         ...                    ...              ...              ...
# 178554  2605019                    746             7017  3/31/2018 23:48
# 178555  2605020                    803             7009  3/31/2018 23:51
# 178556  2605021                    411             7062  3/31/2018 23:54
# 178557  2605022                    164             7002  3/31/2018 23:54
# 178558  2605023                   1134             7029  3/31/2018 23:55
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
df=pd.read_csv("F:\KULIAH\PENGANGGURAN\Digitalent\Kelas A\Materi IBM\Challenge\\q22018.csv")

# %%
df.head()
# Out:
#    trip_id  trip_duration_seconds  from_station_id trip_start_time  \
# 0  2383648                    393             7018   1/1/2018 0:47
# 1  2383649                    625             7184   1/1/2018 0:52
# 2  2383650                    233             7235   1/1/2018 0:55
# 3  2383651                   1138             7202   1/1/2018 0:57
# 4  2383652                    703             7004   1/1/2018 1:00
#
#                          from_station_name trip_stop_time  to_station_id  \
# 0                   Bremner Blvd / Rees St  1/1/2018 0:54           7176
# 1               Ossington Ave / College St  1/1/2018 1:03           7191
# 2  Bay St / College St (West Side) - SMART  1/1/2018 0:59           7021
# 3         Queen St W / York St (City Hall)  1/1/2018 1:16           7020
# 4                  University Ave / Elm St  1/1/2018 1:12           7060
#
#                 to_station_name      user_type
# 0  Bathurst St / Fort York Blvd  Annual Member
# ...

# %%
df.dtypes
# Out:
# trip_id                   int64
# trip_duration_seconds     int64
# from_station_id           int64
# trip_start_time          object
# from_station_name        object
# trip_stop_time           object
# to_station_id             int64
# to_station_name          object
# user_type                object
# dtype: object

# %%
df.set_index(["trip_id"]).count("from_station_id"=="to_station_id")
# Out:
# trip_duration_seconds    178559
# from_station_id          178559
# trip_start_time          178559
# from_station_name        178559
# trip_stop_time           178559
# to_station_id            178559
# to_station_name          178559
# user_type                178559
# dtype: int64

# %%
import numpy as np

# %%
df['hitung'] = np.where((df['from_station_id'] == df['to_station_id']), 1, 0)

# %%
df
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2383648                    393             7018    1/1/2018 0:47
# 1       2383649                    625             7184    1/1/2018 0:52
# 2       2383650                    233             7235    1/1/2018 0:55
# 3       2383651                   1138             7202    1/1/2018 0:57
# 4       2383652                    703             7004    1/1/2018 1:00
# ...         ...                    ...              ...              ...
# 178554  2605019                    746             7017  3/31/2018 23:48
# 178555  2605020                    803             7009  3/31/2018 23:51
# 178556  2605021                    411             7062  3/31/2018 23:54
# 178557  2605022                    164             7002  3/31/2018 23:54
# 178558  2605023                   1134             7029  3/31/2018 23:55
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
df['to_station_id'].isnull().values.any()
# Out:
# False

# %%
dups_color = df.pivot_table(index=['hitung'], aggfunc='size')
print (dups_color)
# Out:
# hitung
# 0    176260
# 1      2299
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
labels = 'Returned Immediately','Not Returned Immediately'
sizes = [176260/(176260+2299),2299/(176260+2299) ]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
route = df.copy()
route = route[['from_station_name', 'to_station_name']]
route
# Out:
#                               from_station_name  \
# 0                        Bremner Blvd / Rees St
# 1                    Ossington Ave / College St
# 2       Bay St / College St (West Side) - SMART
# 3              Queen St W / York St (City Hall)
# 4                       University Ave / Elm St
# ...                                         ...
# 178554                Widmer St / Adelaide St W
# 178555                    King St E / Jarvis St
# 178556       University Ave / College St (West)
# 178557               St. George St / Bloor St W
# 178558             St. James Park (King St. E.)
#
#                             to_station_name
# 0              Bathurst St / Fort York Blvd
# 1                Central Tech  (Harbord St)
# 2                        Bay St / Albert St
# 3                   Phoebe St / Spadina Ave
# 4               Princess St / Adelaide St E
# ...                                     ...
# 178554      Bay St / College St (East Side)
# ...

# %%
import pandas as pd

# %%
route['from_station_name'].value_counts()
# Out:
# Sherbourne St / Wellesley St E                2821
# Union Station                                 2677
# Bay St / Wellesley St W                       2587
# Simcoe St / Wellington St South               2337
# Bay St / College St (East Side)               2128
#                                               ...
# Dundas St W / Roncesvalles Green P - SMART      34
# Danforth Ave / Barrington Ave                   33
# Victoria Park Subway Station - SMART            28
# High Park - West Rd                             25
# Wolfpack - 7219                                  1
# Name: from_station_name, Length: 270, dtype: int64

# %%
df_from=route['from_station_name'].value_counts()

# %%
df_from=df_from.to_frame().reset_index().copy()

# %%
df_from['from_station_name']
# Out:
# 0      2821
# 1      2677
# 2      2587
# 3      2337
# 4      2128
#        ...
# 265      34
# 266      33
# 267      28
# 268      25
# 269       1
# Name: from_station_name, Length: 270, dtype: int64

# %%
df_from.index[0:4]
# Out:
# Index(['Sherbourne St / Wellesley St E', 'Union Station',
#        'Bay St / Wellesley St W', 'Simcoe St / Wellington St South'],
#       dtype='object')

# %%
df_from[0:4]
# Out:
#                              index  from_station_name
# 0   Sherbourne St / Wellesley St E               2821
# 1                    Union Station               2677
# 2          Bay St / Wellesley St W               2587
# 3  Simcoe St / Wellington St South               2337

# %%
plt.figure(figsize=(8, 6))
splot=sns.barplot(x="index", y="from_station_name", data=df_from[0:5])
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title('The most Crowded Departure Station')
plt.xticks(rotation=45)
plt.xlabel("Station Name", size=14)
plt.ylabel("Number of Bike", size=14)
# Out:
# Text(0, 0.5, 'Number of Bike')

# %%
df_from[0:4]
# Out:
# Sherbourne St / Wellesley St E     2821
# Union Station                      2677
# Bay St / Wellesley St W            2587
# Simcoe St / Wellington St South    2337
# Name: from_station_name, dtype: int64

# %%
df_to=route['to_station_name'].value_counts()

# %%
df_to=df_to.to_frame().reset_index().copy()

# %%
plt.figure(figsize=(8, 6))
splot1=sns.barplot(x="index", y="to_station_name", data=df_to[0:5])
for p in splot1.patches:
    splot1.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title('The most Crowded Destination Station')
plt.xticks(rotation=45)
plt.xlabel("Station Name", size=14)
plt.ylabel("Number of Bike", size=14)
# Out:
# Text(0, 0.5, 'Number of Bike')

# %%
df[['Tanggal','Jam']]= df.trip_start_time.str.split(expand=True) 
df
# Out:
#         trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 0       2383648                    393             7018    1/1/2018 0:47
# 1       2383649                    625             7184    1/1/2018 0:52
# 2       2383650                    233             7235    1/1/2018 0:55
# 3       2383651                   1138             7202    1/1/2018 0:57
# 4       2383652                    703             7004    1/1/2018 1:00
# ...         ...                    ...              ...              ...
# 178554  2605019                    746             7017  3/31/2018 23:48
# 178555  2605020                    803             7009  3/31/2018 23:51
# 178556  2605021                    411             7062  3/31/2018 23:54
# 178557  2605022                    164             7002  3/31/2018 23:54
# 178558  2605023                   1134             7029  3/31/2018 23:55
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
tanggal1 = df[df["Tanggal"] == '1/1/2018']
tanggal1
# Out:
#      trip_id  trip_duration_seconds  from_station_id trip_start_time  \
# 0    2383648                    393             7018   1/1/2018 0:47
# 1    2383649                    625             7184   1/1/2018 0:52
# 2    2383650                    233             7235   1/1/2018 0:55
# 3    2383651                   1138             7202   1/1/2018 0:57
# 4    2383652                    703             7004   1/1/2018 1:00
# ..       ...                    ...              ...             ...
# 241  2384013                   1197             7237  1/1/2018 23:05
# 242  2384012                    260             7039  1/1/2018 23:05
# 243  2384014                    584             7057  1/1/2018 23:11
# 244  2384015                    375             7236  1/1/2018 23:18
# 245  2384016                    456             7168  1/1/2018 23:28
#
#                            from_station_name  trip_stop_time  to_station_id  \
# ...

# %%
tanggal1['hitung'] = np.where((tanggal1['from_station_id'] == tanggal1['to_station_id']), 1, 0)
tanggal1
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      trip_id  trip_duration_seconds  from_station_id trip_start_time  \
# 0    2383648                    393             7018   1/1/2018 0:47
# 1    2383649                    625             7184   1/1/2018 0:52
# 2    2383650                    233             7235   1/1/2018 0:55
# 3    2383651                   1138             7202   1/1/2018 0:57
# 4    2383652                    703             7004   1/1/2018 1:00
# ..       ...                    ...              ...             ...
# 241  2384013                   1197             7237  1/1/2018 23:05
# ...

# %%
jumlah = tanggal1.pivot_table(index=['hitung'], aggfunc='size')
print (jumlah)
# Out:
# hitung
# 0    245
# 1      1
# dtype: int64

# %%
labels = 'Returned Immediately','Not Returned Immediately'
sizes = [16/(16+1870),1870/(16+1870)]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
tanggal10 = df[df["Tanggal"] == '1/10/2018']
tanggal10
# Out:
#        trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 8187   2394262                    321             7161   1/10/2018 0:01
# 8188   2394263                   1109             7100   1/10/2018 0:05
# 8189   2394264                    632             7076   1/10/2018 0:09
# 8190   2394265                    361             7276   1/10/2018 0:10
# 8191   2394266                    651             7282   1/10/2018 0:18
# ...        ...                    ...              ...              ...
# 10068  2396515                    153             7044  1/10/2018 23:51
# 10069  2396516                    309             7161  1/10/2018 23:52
# 10070  2396517                    603             7164  1/10/2018 23:57
# 10071  2396519                    399             7009  1/10/2018 23:57
# 10072  2396518                    283             7152  1/10/2018 23:57
#
#                               from_station_name   trip_stop_time  \
# ...

# %%
tanggal10['hitung'] = np.where((tanggal10['from_station_id'] == tanggal10['to_station_id']), 1, 0)
tanggal10
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        trip_id  trip_duration_seconds  from_station_id  trip_start_time  \
# 8187   2394262                    321             7161   1/10/2018 0:01
# 8188   2394263                   1109             7100   1/10/2018 0:05
# 8189   2394264                    632             7076   1/10/2018 0:09
# 8190   2394265                    361             7276   1/10/2018 0:10
# 8191   2394266                    651             7282   1/10/2018 0:18
# ...        ...                    ...              ...              ...
# ...

# %%
jumlah10 = tanggal10.pivot_table(index=['hitung'], aggfunc='size')
print (jumlah10)
# Out:
# hitung
# 0    1870
# 1      16
# dtype: int64

# %%
d = {'Status': ['Dikembalikan', 'Tidak'], 'Jumlah': [16, 1870]}
dfstat = pd.DataFrame(data=d)
ax1 = dfstat.plot.bar(x='Status', y='Jumlah', rot=0,figsize=(10,5))
ax1.set_title('Jumlah sepeda yang dikembalikan ke stasiun awalnya')

for p in ax1.patches:
    ax1.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
rute=tanggal10[['from_station_name', 'to_station_name']]
rute
# Out:
#                               from_station_name  \
# 8187                   Beverley St / College St
# 8188             Dundas St E / Regent Park Blvd
# 8189                    York St / Queens Quay W
# 8190                    Bloor St W / Balmuto St
# 8191             Adelaide St W / Bay St - SMART
# ...                                         ...
# 10068                  Church St / Alexander St
# 10069                  Beverley St / College St
# 10070  Gould St / Yonge St (Ryerson University)
# 10071                     King St E / Jarvis St
# 10072                Ossington Ave / Bloor St W
#
#                       to_station_name
# 8187         Hayter St / Laplante Ave
# 8188         Queen St W / Portland St
# 8189     Bathurst St / Fort York Blvd
# 8190         Hayter St / Laplante Ave
# 8191      Spadina Ave / Adelaide St W
# ...                               ...
# 10068          Jarvis St / Carlton St
# 10069         Phoebe St / Spadina Ave
# ...

# %%
rute1=tanggal10[['from_station_id', 'to_station_id']]
rute1
# Out:
#        from_station_id  to_station_id
# 8187              7161           7162
# 8188              7100           7049
# 8189              7076           7176
# 8190              7276           7162
# 8191              7282           7260
# ...                ...            ...
# 10068             7044           7055
# 10069             7161           7020
# 10070             7164           7100
# 10071             7009           7108
# 10072             7152           7204
#
# [1886 rows x 2 columns]

# %%
dfkeluar = rute.groupby('from_station_name').count()
dfkeluar
# Out:
#                                              to_station_name
# from_station_name
# 111 Bond St (North of Dundas St E)  - SMART                2
# 161 Bleecker St (South of Wellesley)                       4
# 25 York St   Union Station South                         11
# 424 Wellington St W                                        6
# 51 Parliament St                                           3
# ...                                                      ...
# Yonge St / Harbour St                                     11
# Yonge St / Wood St                                        10
# Yonge St / Yorkville Ave                                   5
# York St / King St W - SMART                               15
# York St / Queens Quay W                                   12
#
# [237 rows x 1 columns]

# %%
dfmasuk = tanggal10.groupby('to_station_name').count()
dfmasuk
# Out:
#                                              trip_id  trip_duration_seconds  \
# to_station_name
# 111 Bond St (North of Dundas St E)  - SMART        1                      1
# 161 Bleecker St (South of Wellesley)               3                      3
# 25 York St   Union Station South                 11                     11
# 424 Wellington St W                                6                      6
# 51 Parliament St                                   5                      5
# ...                                              ...                    ...
# Yonge St / Harbour St                              8                      8
# Yonge St / Wood St                                 8                      8
# Yonge St / Yorkville Ave                           5                      5
# York St / King St W - SMART                       17                     17
# York St / Queens Quay W                           17                     17
#
# ...

# %%
rute['bicycle_out']=rute.groupby(by='from_station_name')['from_station_name'].transform('count')
rute
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               from_station_name  \
# 8187                   Beverley St / College St
# 8188             Dundas St E / Regent Park Blvd
# 8189                    York St / Queens Quay W
# 8190                    Bloor St W / Balmuto St
# 8191             Adelaide St W / Bay St - SMART
# ...                                         ...
# 10068                  Church St / Alexander St
# 10069                  Beverley St / College St
# 10070  Gould St / Yonge St (Ryerson University)
# 10071                     King St E / Jarvis St
# ...

# %%
rute['bicycle_in']=rute.groupby(by='to_station_name')['to_station_name'].transform('count')
rute
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               from_station_name  \
# 8187                   Beverley St / College St
# 8188             Dundas St E / Regent Park Blvd
# 8189                    York St / Queens Quay W
# 8190                    Bloor St W / Balmuto St
# 8191             Adelaide St W / Bay St - SMART
# ...                                         ...
# 10068                  Church St / Alexander St
# 10069                  Beverley St / College St
# 10070  Gould St / Yonge St (Ryerson University)
# 10071                     King St E / Jarvis St
# ...

# %%
rute['total']=rute['bicycle_out']-rute['bicycle_in']
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
rute
# Out:
#                               from_station_name  \
# 8187                   Beverley St / College St
# 8188             Dundas St E / Regent Park Blvd
# 8189                    York St / Queens Quay W
# 8190                    Bloor St W / Balmuto St
# 8191             Adelaide St W / Bay St - SMART
# ...                                         ...
# 10068                  Church St / Alexander St
# 10069                  Beverley St / College St
# 10070  Gould St / Yonge St (Ryerson University)
# 10071                     King St E / Jarvis St
# 10072                Ossington Ave / Bloor St W
#
#                       to_station_name  bicycle_out  bicycle_in  total
# 8187         Hayter St / Laplante Ave           11          17     -6
# 8188         Queen St W / Portland St           14          22     -8
# 8189     Bathurst St / Fort York Blvd           12          11      1
# 8190         Hayter St / Laplante Ave            8          17     -9
# ...

# %%
rute.loc[rute['from_station_name'] == 'Ossington Ave / Bloor St W']
# Out:
#                 from_station_name                  to_station_name  \
# 8392   Ossington Ave / Bloor St W       Beverley  St / Dundas St W
# 8575   Ossington Ave / Bloor St W     Willcocks St / St. George St
# 8980   Ossington Ave / Bloor St W         Queen St W / Portland St
# 9111   Ossington Ave / Bloor St W       Ossington Ave / College St
# 9323   Ossington Ave / Bloor St W          College St / Markham St
# 9628   Ossington Ave / Bloor St W  Rusholme Park Cres / College St
# 9812   Ossington Ave / Bloor St W      Ossington Ave / Harrison St
# 10072  Ossington Ave / Bloor St W         College St / Crawford St
#
#        bicycle_out  bicycle_in  total
# 8392             8          16     -8
# 8575             8          17     -9
# 8980             8          22    -14
# 9111             8           5      3
# 9323             8           5      3
# 9628             8           7      1
# 9812             8           1      7
# 10072            8           9     -1

# %%
rute.loc[rute['to_station_name'] == 'Ossington Ave / Bloor St W']
# Out:
#                  from_station_name             to_station_name  bicycle_out  \
# 8311       College St / Markham St  Ossington Ave / Bloor St W            7
# 9297  St. James Park (King St. E.)  Ossington Ave / Bloor St W           16
# 9686            Yonge St / Wood St  Ossington Ave / Bloor St W           10
# 9920       Harbord St / Clinton St  Ossington Ave / Bloor St W            7
#
#       bicycle_in  total
# 8311           4      3
# 9297           4     12
# 9686           4      6
# 9920           4      3

# %%
keluarb=rute.groupby('from_station_name').count()
keluarb1=keluarb.reset_index()
keluarb11=keluarb1.rename(columns={"from_station_name": "stasiun", "to_station_name": "bicycle_out"})
keluarb11
# Out:
#                                          stasiun  bicycle_out
# 0    111 Bond St (North of Dundas St E)  - SMART            2
# 1           161 Bleecker St (South of Wellesley)            4
# 2              25 York St   Union Station South           11
# 3                            424 Wellington St W            6
# 4                               51 Parliament St            3
# ..                                           ...          ...
# 232                        Yonge St / Harbour St           11
# 233                           Yonge St / Wood St           10
# 234                     Yonge St / Yorkville Ave            5
# 235                  York St / King St W - SMART           15
# 236                      York St / Queens Quay W           12
#
# [237 rows x 2 columns]

# %%
masukb=rute.groupby('to_station_name').count()
masukb1=masukb.reset_index()
masukb11=masukb1.rename(columns={"to_station_name": "stasiun", "from_station_name": "bicycle_in"})
masukb11
# Out:
#                                          stasiun  bicycle_in
# 0    111 Bond St (North of Dundas St E)  - SMART           1
# 1           161 Bleecker St (South of Wellesley)           3
# 2              25 York St   Union Station South          11
# 3                            424 Wellington St W           6
# 4                               51 Parliament St           5
# ..                                           ...         ...
# 225                        Yonge St / Harbour St           8
# 226                           Yonge St / Wood St           8
# 227                     Yonge St / Yorkville Ave           5
# 228                  York St / King St W - SMART          17
# 229                      York St / Queens Quay W          17
#
# [230 rows x 2 columns]

# %%
merge = pd.merge(masukb11, keluarb11)
merge
# Out:
#                                          stasiun  bicycle_in  bicycle_out
# 0    111 Bond St (North of Dundas St E)  - SMART           1            2
# 1           161 Bleecker St (South of Wellesley)           3            4
# 2              25 York St   Union Station South          11           11
# 3                            424 Wellington St W           6            6
# 4                               51 Parliament St           5            3
# ..                                           ...         ...          ...
# 220                        Yonge St / Harbour St           8           11
# 221                           Yonge St / Wood St           8           10
# 222                     Yonge St / Yorkville Ave           5            5
# 223                  York St / King St W - SMART          17           15
# 224                      York St / Queens Quay W          17           12
#
# [225 rows x 3 columns]

# %%
mergef=pd.merge(masukb11, keluarb11,how='outer')
mergef
# Out:
#                                          stasiun  bicycle_in  bicycle_out
# 0    111 Bond St (North of Dundas St E)  - SMART         1.0          2.0
# 1           161 Bleecker St (South of Wellesley)         3.0          4.0
# 2              25 York St   Union Station South        11.0         11.0
# 3                            424 Wellington St W         6.0          6.0
# 4                               51 Parliament St         5.0          3.0
# ..                                           ...         ...          ...
# 237                         Pears Av / Avenue Rd         NaN          1.0
# 238              Roncesvalles Ave / Marmaduke St         NaN          3.0
# 239                       Roxton Rd / Harbord St         NaN          3.0
# 240          Wallace Ave / Symington Ave - SMART         NaN          1.0
# 241    Wright / Sorauren (Sorauren Park) - SMART         NaN          1.0
#
# [242 rows x 3 columns]

# %%
mergef1=mergef.fillna(0)
mergef1
# Out:
#                                          stasiun  bicycle_in  bicycle_out
# 0    111 Bond St (North of Dundas St E)  - SMART         1.0          2.0
# 1           161 Bleecker St (South of Wellesley)         3.0          4.0
# 2              25 York St   Union Station South        11.0         11.0
# 3                            424 Wellington St W         6.0          6.0
# 4                               51 Parliament St         5.0          3.0
# ..                                           ...         ...          ...
# 237                         Pears Av / Avenue Rd         0.0          1.0
# 238              Roncesvalles Ave / Marmaduke St         0.0          3.0
# 239                       Roxton Rd / Harbord St         0.0          3.0
# 240          Wallace Ave / Symington Ave - SMART         0.0          1.0
# 241    Wright / Sorauren (Sorauren Park) - SMART         0.0          1.0
#
# [242 rows x 3 columns]

# %%
mergef1['status']=mergef1['bicycle_in']-mergef1['bicycle_out']
mergef1
# Out:
#                                          stasiun  bicycle_in  bicycle_out  \
# 0    111 Bond St (North of Dundas St E)  - SMART         1.0          2.0
# 1           161 Bleecker St (South of Wellesley)         3.0          4.0
# 2              25 York St   Union Station South        11.0         11.0
# 3                            424 Wellington St W         6.0          6.0
# 4                               51 Parliament St         5.0          3.0
# ..                                           ...         ...          ...
# 237                         Pears Av / Avenue Rd         0.0          1.0
# 238              Roncesvalles Ave / Marmaduke St         0.0          3.0
# 239                       Roxton Rd / Harbord St         0.0          3.0
# 240          Wallace Ave / Symington Ave - SMART         0.0          1.0
# 241    Wright / Sorauren (Sorauren Park) - SMART         0.0          1.0
#
#      status
# 0      -1.0
# 1      -1.0
# 2       0.0
# 3       0.0
# 4       2.0
# ...

# %%
mergef1
# Out:
#                                          stasiun  bicycle_in  bicycle_out  \
# 0    111 Bond St (North of Dundas St E)  - SMART         1.0          2.0
# 1           161 Bleecker St (South of Wellesley)         3.0          4.0
# 2              25 York St   Union Station South        11.0         11.0
# 3                            424 Wellington St W         6.0          6.0
# 4                               51 Parliament St         5.0          3.0
# ..                                           ...         ...          ...
# 237                         Pears Av / Avenue Rd         0.0          1.0
# 238              Roncesvalles Ave / Marmaduke St         0.0          3.0
# 239                       Roxton Rd / Harbord St         0.0          3.0
# 240          Wallace Ave / Symington Ave - SMART         0.0          1.0
# 241    Wright / Sorauren (Sorauren Park) - SMART         0.0          1.0
#
#      status
# 0      -1.0
# 1      -1.0
# 2       0.0
# 3       0.0
# 4       2.0
# ...

# %%
mergef2umum=mergef1.sort_values(by=['status'])
mergef2umum
# Out:
#                             stasiun  bicycle_in  bicycle_out  status
# 23          Bay St / Wellesley St W        18.0         33.0   -15.0
# 177  Sherbourne St / Wellesley St E        11.0         24.0   -13.0
# 80     Fort York  Blvd / Capreol Ct         9.0         19.0   -10.0
# 104         Jarvis St / Isabella St         8.0         17.0    -9.0
# 170  Robert St / Bloor St W - SMART         3.0         11.0    -8.0
# ..                              ...         ...          ...     ...
# 106    John St  / Mercer St - SMART        22.0         13.0     9.0
# 174        Scott St / The Esplanade        19.0         10.0     9.0
# 7    Adelaide St W / Bay St - SMART        15.0          6.0     9.0
# 119             King St W / York St        21.0         10.0    11.0
# 215        Wellington St W / Bay St        22.0          9.0    13.0
#
# [242 rows x 4 columns]

# %%
mergef2umum.head(10)
# Out:
#                             stasiun  bicycle_in  bicycle_out  status
# 23          Bay St / Wellesley St W        18.0         33.0   -15.0
# 177  Sherbourne St / Wellesley St E        11.0         24.0   -13.0
# 80     Fort York  Blvd / Capreol Ct         9.0         19.0   -10.0
# 104         Jarvis St / Isabella St         8.0         17.0    -9.0
# 170  Robert St / Bloor St W - SMART         3.0         11.0    -8.0
# 173          Salem Ave / Bloor St W         1.0          8.0    -7.0
# 17      Bay St / Charles St - SMART         2.0          9.0    -7.0
# 85       Front St W / Blue Jays Way        20.0         27.0    -7.0
# 48         Church St / Alexander St         5.0         12.0    -7.0
# 204          Trinity St /Front St E         1.0          7.0    -6.0

# %%
mergef2=mergef1.sort_values(by=['status'])
mergef2
# Out:
#                             stasiun  bicycle_in  bicycle_out  status
# 23          Bay St / Wellesley St W        18.0         33.0   -15.0
# 177  Sherbourne St / Wellesley St E        11.0         24.0   -13.0
# 80     Fort York  Blvd / Capreol Ct         9.0         19.0   -10.0
# 104         Jarvis St / Isabella St         8.0         17.0    -9.0
# 170  Robert St / Bloor St W - SMART         3.0         11.0    -8.0
# ..                              ...         ...          ...     ...
# 106    John St  / Mercer St - SMART        22.0         13.0     9.0
# 174        Scott St / The Esplanade        19.0         10.0     9.0
# 7    Adelaide St W / Bay St - SMART        15.0          6.0     9.0
# 119             King St W / York St        21.0         10.0    11.0
# 215        Wellington St W / Bay St        22.0          9.0    13.0
#
# [242 rows x 4 columns]

# %%
mergef2.tail(10)
# Out:
#                                        stasiun  bicycle_in  bicycle_out  \
# 75                        Edward St / Yonge St        20.0         13.0
# 206                              Union Station        58.0         51.0
# 209              University Ave / Gerrard St W        18.0         10.0
# 33                        Bond St / Queen St E        18.0         10.0
# 63   Dockside Dr / Queens Quay E (Sugar Beach)        17.0          8.0
# 106               John St  / Mercer St - SMART        22.0         13.0
# 174                   Scott St / The Esplanade        19.0         10.0
# 7               Adelaide St W / Bay St - SMART        15.0          6.0
# 119                        King St W / York St        21.0         10.0
# 215                   Wellington St W / Bay St        22.0          9.0
#
#      status
# 75      7.0
# 206     7.0
# 209     8.0
# 33      8.0
# 63      9.0
# 106     9.0
# 174     9.0
# 7       9.0
# 119    11.0
# 215    13.0

# %%
mergef2t=mergef2.tail(10)
mergef2t=mergef2t.rename(columns={"status": "total"})
mergef2t
# Out:
#                                        stasiun  bicycle_in  bicycle_out  total
# 75                        Edward St / Yonge St        20.0         13.0    7.0
# 206                              Union Station        58.0         51.0    7.0
# 209              University Ave / Gerrard St W        18.0         10.0    8.0
# 33                        Bond St / Queen St E        18.0         10.0    8.0
# 63   Dockside Dr / Queens Quay E (Sugar Beach)        17.0          8.0    9.0
# 106               John St  / Mercer St - SMART        22.0         13.0    9.0
# 174                   Scott St / The Esplanade        19.0         10.0    9.0
# 7               Adelaide St W / Bay St - SMART        15.0          6.0    9.0
# 119                        King St W / York St        21.0         10.0   11.0
# 215                   Wellington St W / Bay St        22.0          9.0   13.0

# %%
ax2 = mergef2t.plot.bar(x='stasiun', y='total', rot=45,figsize=(20,10))

ax2.set_title('The stations with the number of bicycles increases at the end of the service')

for p in ax2.patches:
    ax2.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
mergef2.head(10)
# Out:
#                             stasiun  bicycle_in  bicycle_out  status
# 23          Bay St / Wellesley St W        18.0         33.0   -15.0
# 177  Sherbourne St / Wellesley St E        11.0         24.0   -13.0
# 80     Fort York  Blvd / Capreol Ct         9.0         19.0   -10.0
# 104         Jarvis St / Isabella St         8.0         17.0    -9.0
# 170  Robert St / Bloor St W - SMART         3.0         11.0    -8.0
# 173          Salem Ave / Bloor St W         1.0          8.0    -7.0
# 17      Bay St / Charles St - SMART         2.0          9.0    -7.0
# 85       Front St W / Blue Jays Way        20.0         27.0    -7.0
# 48         Church St / Alexander St         5.0         12.0    -7.0
# 204          Trinity St /Front St E         1.0          7.0    -6.0

# %%
mergef2h=mergef2.head(10)
mergef2h['status']=mergef2h['status'].abs()
mergef2h=mergef2h.rename(columns={"status": "total"})
mergef2h
# Out:
# C:\Users\Public\miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             stasiun  bicycle_in  bicycle_out  total
# 23          Bay St / Wellesley St W        18.0         33.0   15.0
# 177  Sherbourne St / Wellesley St E        11.0         24.0   13.0
# 80     Fort York  Blvd / Capreol Ct         9.0         19.0   10.0
# 104         Jarvis St / Isabella St         8.0         17.0    9.0
# 170  Robert St / Bloor St W - SMART         3.0         11.0    8.0
# 173          Salem Ave / Bloor St W         1.0          8.0    7.0
# 17      Bay St / Charles St - SMART         2.0          9.0    7.0
# 85       Front St W / Blue Jays Way        20.0         27.0    7.0
# ...

# %%
ax = mergef2h.plot.bar(x='stasiun', y='total', rot=45,figsize=(20,10))

ax.set_title('The stations with the number of bicycles decreases at the end of the service')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
cobal=pd.DataFrame({'Nama stasiun': keluarb1['from_station_name'],
                    'Keluar' : keluarb1['keluar'],
                   'Masuk' : masukb1['masuk']
                   })
cobal
# Out:
#                                     Nama stasiun  Keluar  Masuk
# 0    111 Bond St (North of Dundas St E)  - SMART       2    1.0
# 1           161 Bleecker St (South of Wellesley)       4    3.0
# 2              25 York St   Union Station South      11   11.0
# 3                            424 Wellington St W       6    6.0
# 4                               51 Parliament St       3    5.0
# ..                                           ...     ...    ...
# 232                        Yonge St / Harbour St      11    NaN
# 233                           Yonge St / Wood St      10    NaN
# 234                     Yonge St / Yorkville Ave       5    NaN
# 235                  York St / King St W - SMART      15    NaN
# 236                      York St / Queens Quay W      12    NaN
#
# [237 rows x 3 columns]

# %%
print(type(keluarb))
# Out:
# <class 'pandas.core.series.Series'>

# %%
coba=pd.DataFrame({'Nama Stasiun' : rute['from_station_name'],
                   'Keluar' : rute['keluar'],
                   'Masuk' : rute['masuk'],
                    'Total':rute['total']})

# %%
coba
# Out:
#                                    Nama Stasiun  Keluar  Masuk  Total
# 8187                   Beverley St / College St      11     17     -6
# 8188             Dundas St E / Regent Park Blvd      14     22     -8
# 8189                    York St / Queens Quay W      12     11      1
# 8190                    Bloor St W / Balmuto St       8     17     -9
# 8191             Adelaide St W / Bay St - SMART       6     17    -11
# ...                                         ...     ...    ...    ...
# 10068                  Church St / Alexander St      12      7      5
# 10069                  Beverley St / College St      11     28    -17
# 10070  Gould St / Yonge St (Ryerson University)      16     15      1
# 10071                     King St E / Jarvis St      18      5     13
# 10072                Ossington Ave / Bloor St W       8      9     -1
#
# [1886 rows x 4 columns]

# %%
coba.sort_values(by=['Total'])
# Out:
#                           Nama Stasiun  Keluar  Masuk  Total
# 8388          King / Cowan Ave - SMART       2     58    -56
# 9423   Church St / Dundas St E - SMART       3     58    -55
# 9421         Cherry St / Distillery Ln       4     58    -54
# 8194        Marlborough Ave / Yonge St       5     58    -53
# 9051          Spadina Ave / Sussex Ave       5     58    -53
# ...                                ...     ...    ...    ...
# 8202                     Union Station      51      5     46
# 8235                     Union Station      51      5     46
# 10050                    Union Station      51      3     48
# 8943                     Union Station      51      3     48
# 10030                    Union Station      51      1     50
#
# [1886 rows x 4 columns]

# %%
coba.loc[coba['Nama Stasiun'] == 'Wellington St W / Bay St']
# Out:
#                   Nama Stasiun  Keluar  Masuk  Total
# 8528  Wellington St W / Bay St       9      6      3
# 8903  Wellington St W / Bay St       9     28    -19
# 9036  Wellington St W / Bay St       9     24    -15
# 9108  Wellington St W / Bay St       9     17     -8
# 9212  Wellington St W / Bay St       9      6      3
# 9535  Wellington St W / Bay St       9     10     -1
# 9640  Wellington St W / Bay St       9      8      1
# 9697  Wellington St W / Bay St       9     14     -5
# 9799  Wellington St W / Bay St       9     11     -2

# %%
rute.loc[rute['to_station_name'] == 'Church St / Alexander St']
# Out:
#                       from_station_name           to_station_name
# 8558               Gould St / Mutual St  Church St / Alexander St
# 9222        Dundas St E / Parliament St  Church St / Alexander St
# 9333   Front St W / Bay St (South Side)  Church St / Alexander St
# 9662                 Bay St / Albert St  Church St / Alexander St
# 9765  Richmond St E / Jarvis St Green P  Church St / Alexander St
